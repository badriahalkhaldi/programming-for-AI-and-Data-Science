# %%
print ("there is one thing every coder must understand: \nthe print command.\n\nthere is one thing every coder must understand: \nthe print commend.")
# Out:
# there is one thing every coder must understand:
# the print command.
#
# there is one thing every coder must understand:
# the print commend.

# %% [markdown]
# Dear "doubleSlash"magazine,
#
# 	Your pudication confuses me. Is it
# a \\ slash or a //// slash?
#
# Sincerely,
# Susan"Suzy"Smith

# %%
print("What is the difference between")
print("a\' and a \"\? Or between a \" and a \\ \"\?")
print()
print("One is what we see when we're typing our program.\nThe other is what appears on the \"console.\"")
# Out:
# What is the difference between
# a' and a "\? Or between a " and a \ "\?
#
# One is what we see when we're typing our program.
# The other is what appears on the "console."

# %% [markdown]
# Im Function1
# Im Function1
# Im Function2
# Im Function3
# Im Function1
# Im Function1
# Im Function2
# Im Function1
# Im Function2
# Im Function3
# Im Function1

# %%
def b1():
    print("*****\n*****\n * *\n  *\n * *")
def b2():
    print("*****\n*****\n\n  *\n  *\n  *")
def main():
    b1()
    print()
    b1()
    b2()
    b1()
main()
# Out:
# *****
# *****
#  * *
#   *
#  * *
#
# *****
# *****
#  * *
#   *
#  * *
# *****
# *****
#
#   *
#   *
#   *
# *****
# *****
#  * *
#   *
#  * *

# %%
def head():
    print("   *******\n  *  O O  *\n  *   ^   *\n  * \033[4m\---/\033[0m *\n   *******")
def body():
    print("      *\n      *\n      *\n     ***\n    *   *\n   *     *")
def X():
    print("  \033[4mX\033[0m       \033[4mX\033[0m")
def M():
    print("  \033[4mM\033[0m       \033[4mM\033[0m")
def h():
    print("\033[4m-------------\033[0m")
def main():
    head()
    body()
    X()
    body()
    M()
    h()
main()
# Out:
#    *******
#   *  O O  *
#   *   ^   *
#   * \---/ *
#    *******
#       *
#       *
#       *
#      ***
#     *   *
#    *     *
#   X       X
#       *
#       *
#       *
#      ***
#     *   *
#    *     *
#   M       M
# -------------
