# %%
print(("* ")*5)
print(("* ")*5)
print(("* ")*5)
print(("* ")*5)
print(("* ")*5)
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
a = ' one'
b = ' two'
c = ' three '
print(a,b,c)    # Using commas
print(a+b+c)    # Using plus sign
# Out:
#  one  two  three
#  one two three

# %% [markdown]
# one  two  three
# one  two  three
