# %%
#task 1
fruits = ["apple", "banana", "mango"]
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
#task 2
colors = ["red", "green" , "blue"]
print(colors[0])
print(colors[-1])
# Out:
# red
# blue

# %%
#task 3
animals = ["cat" , "dog" , "bird"]
animals[1] = "fish"
print(animals)
# Out:
# ['cat', 'fish', 'bird']

# %%
# task 4
numbers = [1,2,3]
numbers.append(4)
print(numbers)
numbers.remove(2)
print(numbers)
numbers.pop(0)
print(numbers)
# Out:
# [1, 2, 3, 4]
# [1, 3, 4]
# [3, 4]

# %%
#task 5
for fruit in ["apple", "banana" , "mango"]:
    print(fruit)
# Out:
# apple
# banana
# mango

# %%
#task 6
items = ["pen", "book", "eraser"]
print(len(items))
# Out:
# 3

# %%
#task 7
numbers = [5,2,9,1]
numbers. sort()
print(numbers)
print(numbers[1:3])
# Out:
# [1, 2, 5, 9]
# [2, 5]

# %%
#task 8
matrix = [[1,2, "Yousef",8,4.5],[3,4,9.8, "Rawabi",7],[5,6, 9, 8,3]]
print(matrix[1][3])
# Out:
# Rawabi

# %%
#task 9
days = ("Mon", "tue", "wed")
print(days[0])
# Out:
# Mon

# %%
#task 10
colors = ("red", "blue", "green")
colors [0] = "yellow" # will cause error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #task 10
#       2 colors = ("red", "blue", "green")
# ----> 3 colors [0] = "yellow"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# task 11
for day in ("Mon", "Tue", "Wed"):
     print(day)
# Out:
# Mon
# Tue
# Wed

# %%
#task 13
student = ("Ali", ("math", "science"))
print(student[1][0])
# Out:
# math

# %%
# task 14
numbers={1,2,3,3,3,4,4,}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
#task 15
fruits = {"apple", "banana"}
fruits.add("mango")
fruits.remove("banana")
print(fruits)
# Out:
# {'apple', 'mango'}

# %%
#task 16
a= {1,2,3}
b= {3,4,5}
print(a.intersection(b))
print(a.union(b))
# Out:
# {3}
# {1, 2, 3, 4, 5}

# %%
#task 17
x= {"apple", "banana", "cherry"}
y= {"banana","kiwi"}
print(x-y)
# Out:
# {'apple', 'cherry'}

# %%
#task 18
cities = {"Riyadh","Jeddah","Dammam"}
print("Riyadh" in cities)
# Out:
# True

# %%
# task 19
student= {"name":"Ali","age":20,"Grade":"A"}
print(student)
# Out:
# {'name': 'Ali', 'age': 20, 'Grade': 'A'}

# %%
#task 20
person = {"name":"Sara","age":25}
person["age"] = 26
print(person["age"])
# Out:
# 26

# %%
#task 21
car = {"brand":"Toyota","year":2020}
car["color"] = "red"
car.pop("year")
print(car)
# Out:
# {'brand': 'Toyota', 'color': 'red'}

# %%
#task 22
for key, value in student.items():
    print(key,":", value)
# Out:
# name : Ali
# age : 20
# Grade : A

# %%
#task 23
marks = {"Ali":85,"Sara":90,"Ahmed":78}
print (marks["Sara"])
# Out:
# 90
