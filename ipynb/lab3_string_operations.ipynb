# %%
city = "Riyadh"
print(city[0:3])
print(city[2:])
print(city[:4])
# Out:
# Riy
# yadh
# Riya

# %%
text = "Python"
print(text[0])
print(text[-1])
# Out:
# P
# n

# %%
print("Hi! "*3)
# Out:
# Hi! Hi! Hi!

# %%
text = "python programming"
print(text.upper())
print(text.title())
print(text.replace("python", "java"))
# Out:
# PYTHON PROGRAMMING
# Python Programming
# java programming

# %%
sentece = "python is fun"
print("fun" in sentece)
print("hard" not in sentece)
# Out:
# True
# True

# %%
word = "python "
print(word[::-1])
# Out:
#  nohtyp

# %%
txt = "banana"
print(txt.count("a"))
# Out:
# 3

# %%
words =["python","is","fun"]
send = " ".join(words)
print(send)
# Out:
# python is fun

# %%
print(ord("A"))
print(ord("a"))
# Out:
# 65
# 97

# %%
print(ord("😊"))
# Out:
# 128522

# %%
print(chr(128522))
# Out:
# 😊
